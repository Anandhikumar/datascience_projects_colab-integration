# %% [markdown]
# <a href="https://colab.research.google.com/github/Anandhikumar/datascience_projects_colab-integration/blob/main/hello_world_dsml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, World!")
print("Welcome to Data Science and Machine Learning projects!")
# Out:
# Hello, World!
# Welcome to Data Science and Machine Learning projects!
